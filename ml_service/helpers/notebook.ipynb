# %%
import joblib
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import os

VECTORIZER_PATH = "src/vectorizer.pkl"
DB_PATH = "src/fix_database.pkl"
DATA_CSV_PATH = "data/code_bug_fix_pairs_clean.csv"

print(f"Current working directory: {os.getcwd()}")
print(f"Checking paths: \nVectorizer: {os.path.exists(VECTORIZER_PATH)}\nDB: {os.path.exists(DB_PATH)}")
# Out:
# Current working directory: d:\7_semester\SII\Curse\ml_service
# Checking paths:
# Vectorizer: True
# DB: True

# %%
try:
    vectorizer = joblib.load(VECTORIZER_PATH)
    db = joblib.load(DB_PATH)
    
    db_vectors = vectorizer.transform(db["buggy_code"])
    
    print("✅ Модель успешно загружена!")
    print(f"Размер базы знаний: {len(db)} записей")
    print(f"Количество признаков (ngram): {len(vectorizer.get_feature_names_out())}")
    
except Exception as e:
    print(f"❌ Ошибка загрузки: {e}")
    print("Убедитесь, что вы запустили train_model.py хотя бы один раз.")
# Out:
# ✅ Модель успешно загружена!
# Размер базы знаний: 186 записей
# Количество признаков (ngram): 3869

# %%
def check_confidence(query_text: str, top_n=5):
    """
    Анализирует запрос и показывает степень уверенности модели.
    """
    print(f"\n🔎 Анализ запроса: '{query_text}'")
    print("-" * 50)
    
    # 1. Векторизация запроса
    try:
        query_vec = vectorizer.transform([query_text])
    except ValueError:
        print("Ошибка векторизации. Возможно, текст пустой или содержит недопустимые символы.")
        return

    # 2. Расчет сходства (Cosine Similarity)
    # Результат - массив чисел от 0 до 1, где 1 - полное совпадение
    similarities = cosine_similarity(query_vec, db_vectors).flatten()
    
    # 3. Поиск лучших совпадений
    # Получаем индексы сортировки (от меньшего к большему), берем последние top_n и разворачиваем
    best_indices = similarities.argsort()[-top_n:][::-1]
    
    # 4. Вывод результатов
    found_good_match = False
    
    for i, idx in enumerate(best_indices):
        confidence = similarities[idx]
        row = db.iloc[idx]
        
        prefix = "⭐ BEST MATCH" if i == 0 else f"   Option {i+1}"
        
        print(f"{prefix} | Уверенность: {confidence:.4f} ({confidence*100:.1f}%)")
        print(f"   База (buggy_code):  {repr(row['buggy_code'])}")
        print(f"   Исправление:        {repr(row['commit_message'])}")
        print("-" * 30)
        
        if i == 0:
            if confidence >= 0.65:
                print("✅ Вердикт: REPORT SERVICE примет этот ответ.")
            else:
                print("⚠️ Вердикт: Уверенность НИЖЕ порога (0.65). Report Service пойдет в Базу Знаний.")

# Пример использования функции
check_confidence("lst = [1, 2, 3] print(lst[5])")
# Out:
# 🔎 Анализ запроса: 'lst = [1, 2, 3] print(lst[5])'
# --------------------------------------------------
# ⭐ BEST MATCH | Уверенность: 0.8433 (84.3%)
#    База (buggy_code):  'lst = [1, 2, 3]\nprint(lst[5])'
#    Исправление:        'Индекс выходит за пределы списка (IndexError).'
# ------------------------------
# ✅ Вердикт: REPORT SERVICE примет этот ответ.
#    Option 2 | Уверенность: 0.7633 (76.3%)
#    База (buggy_code):  'lst = [1,2,3]\r\nprint(lst[5])'
#    Исправление:        'Исправлен выход за пределы списка (IndexError)'
# ------------------------------
#    Option 3 | Уверенность: 0.3717 (37.2%)
#    База (buggy_code):  'y = [1, 2'
#    Исправление:        'Не закрыта квадратная скобка.'
# ------------------------------
#    Option 4 | Уверенность: 0.3044 (30.4%)
#    База (buggy_code):  'lst = [1,2,3]\r\nfor i in lst\r\n    print(i)'
#    Исправление:        'Пропущено двоеточие в цикле (SyntaxError)'
# ------------------------------
#    Option 5 | Уверенность: 0.2074 (20.7%)
#    База (buggy_code):  'x = [1,2,3]\r\n for i in x:\r\n    print(i)'
#    Исправление:        'Исправлен лишний отступ (IndentationError)'
# ------------------------------

# %%
# Тест 1: Синтаксическая ошибка (как в вашем примере)
check_confidence("invalid syntax")

# Тест 2: Ошибка с двоеточием (попробуйте оба варианта, чтобы почувствовать разницу)
check_confidence("def calculate_sum(a, b)") 
check_confidence("def calculate_sum(a, b):")

# Тест 3: Текст ошибки Python (если вы добавили его в CSV по моему совету)
check_confidence("expected ':'")
# Out:
# 🔎 Анализ запроса: 'invalid syntax'
# --------------------------------------------------
# ⭐ BEST MATCH | Уверенность: 1.0000 (100.0%)
#    База (buggy_code):  'invalid syntax'
#    Исправление:        'Синтаксическая ошибка. Проверьте конструкцию (if, for, def) и скобки.'
# ------------------------------
# ✅ Вердикт: REPORT SERVICE примет этот ответ.
#    Option 2 | Уверенность: 0.7569 (75.7%)
#    База (buggy_code):  'invalid syntavalue'
#    Исправление:        'Синтаксическая ошибка. Проверьте конструкцию (if, for, def) и скобки.'
# ------------------------------
#    Option 3 | Уверенность: 0.7509 (75.1%)
#    База (buggy_code):  'invalid syntacount'
#    Исправление:        'Синтаксическая ошибка. Проверьте конструкцию (if, for, def) и скобки.'
# ------------------------------
#    Option 4 | Уверенность: 0.7137 (71.4%)
#    База (buggy_code):  'invalid syntauser_id'
#    Исправление:        'Синтаксическая ошибка. Проверьте конструкцию (if, for, def) и скобки.'
# ------------------------------
#    Option 5 | Уверенность: 0.0555 (5.5%)
#    База (buggy_code):  'print value'
#    Исправление:        'В Python 3 для print требуются скобки'
# ------------------------------
#
# 🔎 Анализ запроса: 'def calculate_sum(a, b)'
# --------------------------------------------------
# ⭐ BEST MATCH | Уверенность: 1.0000 (100.0%)
#    База (buggy_code):  'def calculate_sum(a, b)'
#    Исправление:        'Пропущено двоеточие в функции.'
# ------------------------------
# ✅ Вердикт: REPORT SERVICE примет этот ответ.
#    Option 2 | Уверенность: 0.7061 (70.6%)
#    База (buggy_code):  'def calculate(a, b)'
#    Исправление:        'Пропущено двоеточие в объявлении функции.'
# ------------------------------
#    Option 3 | Уверенность: 0.1706 (17.1%)
#    База (buggy_code):  'def add(a, b)\n    return a + b'
#    Исправление:        'Пропущено двоеточие в объявлении функции.'
# ------------------------------
#    Option 4 | Уверенность: 0.1067 (10.7%)
#    База (buggy_code):  'def func( a, b ):'
#    Исправление:        'Лишние пробелы внутри скобок.'
# ------------------------------
#    Option 5 | Уверенность: 0.0746 (7.5%)
#    База (buggy_code):  'sum = 0'
#    Исправление:        "Не перекрывайте встроенную функцию 'sum'."
# ------------------------------
#
# 🔎 Анализ запроса: 'def calculate_sum(a, b):'
# --------------------------------------------------
# ⭐ BEST MATCH | Уверенность: 0.9950 (99.5%)
#    База (buggy_code):  'def calculate_sum(a, b)'
#    Исправление:        'Пропущено двоеточие в функции.'
# ------------------------------
# ✅ Вердикт: REPORT SERVICE примет этот ответ.
#    Option 2 | Уверенность: 0.7026 (70.3%)
#    База (buggy_code):  'def calculate(a, b)'
#    Исправление:        'Пропущено двоеточие в объявлении функции.'
# ------------------------------
#    Option 3 | Уверенность: 0.1697 (17.0%)
#    База (buggy_code):  'def add(a, b)\n    return a + b'
#    Исправление:        'Пропущено двоеточие в объявлении функции.'
# ------------------------------
#    Option 4 | Уверенность: 0.1181 (11.8%)
#    База (buggy_code):  'def func( a, b ):'
#    Исправление:        'Лишние пробелы внутри скобок.'
# ------------------------------
#    Option 5 | Уверенность: 0.0742 (7.4%)
#    База (buggy_code):  'sum = 0'
#    Исправление:        "Не перекрывайте встроенную функцию 'sum'."
# ------------------------------
#
# 🔎 Анализ запроса: 'expected ':''
# --------------------------------------------------
# ⭐ BEST MATCH | Уверенность: 1.0000 (100.0%)
#    База (buggy_code):  "expected ':'"
#    Исправление:        'Пропущено двоеточие в конце строки (if, def, class, while).'
# ------------------------------
# ✅ Вердикт: REPORT SERVICE примет этот ответ.
#    Option 2 | Уверенность: 0.7275 (72.7%)
#    База (buggy_code):  "eypected ':'"
#    Исправление:        'Пропущено двоеточие в конце строки (if, def, class, while).'
# ------------------------------
#    Option 3 | Уверенность: 0.5978 (59.8%)
#    База (buggy_code):  "evaluepected ':'"
#    Исправление:        'Пропущено двоеточие в конце строки (if, def, class, while).'
# ------------------------------
#    Option 4 | Уверенность: 0.5667 (56.7%)
#    База (buggy_code):  "euser_idpected ':'"
#    Исправление:        'Пропущено двоеточие в конце строки (if, def, class, while).'
# ------------------------------
#    Option 5 | Уверенность: 0.5100 (51.0%)
#    База (buggy_code):  'unexpected indent'
#    Исправление:        'Ошибка отступа. Уберите лишние пробелы в начале строки.'
# ------------------------------

# %%
def analyze_ngrams(text):
    """Показывает, на какие n-граммы разбивается текст"""
    analyzer = vectorizer.build_analyzer()
    tokens = analyzer(text)
    print(f"Текст: '{text}'")
    print(f"Токены (n-граммы): {tokens}")
    
    # Проверим, какие из этих токенов реально есть в словаре модели
    known_tokens = [t for t in tokens if t in vectorizer.vocabulary_]
    print(f"Знакомые модели токены: {known_tokens}")
    print(f"Процент знакомых: {len(known_tokens) / len(tokens) * 100:.1f}%" if tokens else "0%")

# Проверьте на тексте ошибки
analyze_ngrams("invalid syntax")
# Out:
# Текст: 'invalid syntax'
# Токены (n-граммы): ['in', 'nv', 'va', 'al', 'li', 'id', 'd ', ' s', 'sy', 'yn', 'nt', 'ta', 'ax', 'inv', 'nva', 'val', 'ali', 'lid', 'id ', 'd s', ' sy', 'syn', 'ynt', 'nta', 'tax', 'inva', 'nval', 'vali', 'alid', 'lid ', 'id s', 'd sy', ' syn', 'synt', 'ynta', 'ntax', 'inval', 'nvali', 'valid', 'alid ', 'lid s', 'id sy', 'd syn', ' synt', 'synta', 'yntax']
# Знакомые модели токены: ['in', 'nv', 'va', 'al', 'li', 'id', 'd ', ' s', 'sy', 'yn', 'nt', 'ta', 'ax', 'inv', 'nva', 'val', 'ali', 'lid', 'id ', 'd s', ' sy', 'syn', 'ynt', 'nta', 'tax', 'inva', 'nval', 'vali', 'alid', 'lid ', 'id s', 'd sy', ' syn', 'synt', 'ynta', 'ntax', 'inval', 'nvali', 'valid', 'alid ', 'lid s', 'id sy', 'd syn', ' synt', 'synta', 'yntax']
# Процент знакомых: 100.0%
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
